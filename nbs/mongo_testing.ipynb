# %%
from pymongo import MongoClient
from pprint import pprint
from bson import json_util
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5f6cf26c46aa> in <module>()
# ----> 1 from pymongo import MongoClient
#       2 from pprint import pprint
#       3 from bson import json_util
#       4 import json
#
# ImportError: No module named pymongo

# %%
client = MongoClient()

# %%
db = client.tg3

# %%
cursor = db.projects.find()

# %%
colls = db.collection_names()

# %%
colls
# Out:
# [u'batches',
#  u'managedLists',
#  u'projects_backup',
#  u'samples',
#  u'projects',
#  u'error_logs',
#  u'_managedLists',
#  u'idCollection',
#  u'samples_backup']

# %%
p43_libs = db.samples.find(filter = {"type": "library",
                                    "projectId": 43},
                          projection = ["subprojectId"])
for lib in p43_libs:
    print lib
# Out:
# {u'_id': u'lib10000', u'subprojectId': 29}
# {u'_id': u'lib10001', u'subprojectId': 29}
# {u'_id': u'lib10002', u'subprojectId': 29}
# {u'_id': u'lib10003', u'subprojectId': 29}
# {u'_id': u'lib10004', u'subprojectId': 29}
# {u'_id': u'lib10005', u'subprojectId': 29}
# {u'_id': u'lib10006', u'subprojectId': 29}
# {u'_id': u'lib10007', u'subprojectId': 29}
# {u'_id': u'lib10008', u'subprojectId': 29}
# {u'_id': u'lib10009', u'subprojectId': 29}
# {u'_id': u'lib10010', u'subprojectId': 29}
# {u'_id': u'lib10011', u'subprojectId': 29}
# {u'_id': u'lib10012', u'subprojectId': 29}
# {u'_id': u'lib10013', u'subprojectId': 29}
# {u'_id': u'lib10014', u'subprojectId': 31}
# {u'_id': u'lib10015', u'subprojectId': 31}
# {u'_id': u'lib10016', u'subprojectId': 31}
# {u'_id': u'lib10017', u'subprojectId': 31}
# {u'_id': u'lib10018', u'subprojectId': 31}
# {u'_id': u'lib10019', u'subprojectId': 31}
# {u'_id': u'lib10020', u'subprojectId': 31}
# {u'_id': u'lib10021', u'subprojectId': 31}
# ...

# %%
lib_id = "lib6605"
lib = db.samples.find_one({"_id": lib_id})
cdna = db.samples.find_one({"_id": lib.get("parentId")})
sample = db.samples.find_one({"_id": cdna.get("parentId")})

# %%
cdna
# Out:
# {u'_id': u'tRNA24443',
#  u'barcode': None,
#  u'concentration': 0.0,
#  u'consumed': None,
#  u'container': None,
#  u'dateCreated': datetime.datetime(2015, 3, 9, 16, 44, 41),
#  u'freezer': None,
#  u'internalIndex': 24443,
#  u'lastUpdated': datetime.datetime(2015, 3, 9, 16, 44, 41),
#  u'leftover': 0.0,
#  u'lotNumber': None,
#  u'lysateScore': None,
#  u'notes': None,
#  u'parentId': u'S29306',
#  u'positionx': None,
#  u'positiony': None,
#  u'processingStatus': None,
#  u'projectId': 109,
#  u'projectName': u'Cell SubSet Seq Cohort 1-Cate Speake',
#  u'protocol': None,
#  u'qualityFlag': None,
#  u'ratio260': 0.0,
#  u'ratio28': 0.0,
#  u'removed': False,
#  u'researcher': None,
#  u'rin': 0.0,
#  u'sampleId': u'S29306',
#  u'storage': None,
#  u'trnaDate': None,
#  u'trnaId': u'tRNA24443',
#  u'type': u'tRNA',
#  u'volume': 0.0,
#  u'volumeRemoved': 0.0,
#  u'yield': 0.0}

# %%
p43_29 = db.projects.find_one({"_id": 43}).get('subprojects')[29]

# %%
print json.dumps(p43_29, indent=4, sort_keys=True)
# Out:
# {
#     "experimentControls": "\t\t\t\t",
#     "experimentDescription": "\t\t\t\t",
#     "experimentDesign": "\t\t\t\t",
#     "experimentHypotheses": "\t\t\t\t",
#     "experimentName": "C1 Nov. 24, 2015",
#     "experimentVariables": "\t\t\t\t",
#     "requestDate": "",
#     "subproject": 29,
#     "subprojectId": 29
# }

# %%
p43 = db.projects.find_one({"_id": 43})
print json.dumps(p43, default=json_util.default, indent=4, sort_keys=True)
# Out:
# {
#     "_id": 43,
#     "dateCreated": {
#         "$date": 1337035533000
#     },
#     "dmID": null,
#     "internalIndex": 43,
#     "isActive": true,
#     "lastUpdated": {
#         "$date": 1337036471000
#     },
#     "projectBackground": "",
#     "projectGoals": "",
#     "projectIRB": null,
#     "projectMethods": "",
#     "projectResults": "",
#     "projectTitle": "Eric Wambre",
#     "projectType": "Clinical",
#     "searchId": "p43",
#     "subprojects": [
#         {
#             "dateCreated": {
#                 "$date": 1337035533000
#             },
#             "experimentName": "Eric Wambre",
#             "projectType": "Clinical",
#             "subprojectId": 0
#         },
#         {
#             "experimentControls": "unknown",
#             "experimentDesign": "unknown",
#             "experimentHypothesis": "unknown",
#             "experimentName": "Jun2012 Microarray",
#             "experimentPurpose": "unknown",
# ...

# %%
lib10000 = db.samples.find_one({"_id": "lib10000"})

# %%
print json.dumps(lib10000, indent=4, sort_keys=True, default=json_util.default)
# Out:
# {
#     "Process": "Process",
#     "_id": "lib10000",
#     "batchIndex": 57,
#     "collaborator": null,
#     "dateCreated": {
#         "$date": 1449184242310
#     },
#     "dateUpdated": {
#         "$date": 1449184242310
#     },
#     "internalIndex": 10000,
#     "parentId": "cDNA18696",
#     "projectId": 43,
#     "projectName": "Eric Wambre",
#     "protocol": "C1/NexteraXT",
#     "researcher": null,
#     "sampleId": null,
#     "sampleName": "1*_HC29_C04",
#     "subprojectId": 29,
#     "type": "library"
# }

# %%
c18696 = db.samples.find_one({"_id": "cDNA18696"})

# %%
print json.dumps(c18696, indent=4, sort_keys=True, default=json_util.default)
# Out:
# {
#     "Process": "Process",
#     "_id": "cDNA18696",
#     "batchIndex": 56,
#     "collaborator": null,
#     "dateCreated": {
#         "$date": 1449183664903
#     },
#     "dateUpdated": {
#         "$date": 1449183664903
#     },
#     "internalIndex": 18696,
#     "parentId": "S33861",
#     "projectId": 43,
#     "projectName": "Eric Wambre",
#     "protocol": "C1 Direct Sort",
#     "researcher": null,
#     "sampleId": null,
#     "sampleName": "1*_HC29_C04",
#     "subprojectId": 29,
#     "type": "cDNA"
# }

# %%
s33861 = db.samples.find_one({"_id": "S33861"})

# %%
print json.dumps(s33861, indent=4, sort_keys=True, default=json_util.default)
# Out:
# {
#     "Ignore Field": "NexteraXT",
#     "_id": "S33861",
#     "batchIndex": 55,
#     "c1ChipId": 1771050078,
#     "c1ChipRunDate": "Tue Nov 24 00:00:00 PST 2015",
#     "cellType": "CD4+ CD45RA- CD154+",
#     "collectionDate": "Tue Nov 24 00:00:00 PST 2015",
#     "contentType": "cDNA",
#     "dateCreated": {
#         "$date": 1449183531319
#     },
#     "dateUpdated": {
#         "$date": 1449183531319
#     },
#     "donorId": "HC29",
#     "index5": "S503",
#     "index7": "N705",
#     "internalIndex": 33861,
#     "projectId": 43,
#     "projectName": "Eric Wambre",
#     "sampleName": "1*_HC29_C04",
#     "sampleRepositoryID": "WB165556008",
#     "species": "human",
#     "stimulation": "incubation with Ara h1,2,3,6,8,9 peptides pool",
#     "studyGroup": "Healthy Control",
#     "subprojectId": 29,
#     "type": "sample"
# }

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os, re, argparse, csv
import shutil
from pprint import pprint

# %%
import _mypath
from bripipetools.io import parsers

# %%
dmplexstats_file = "../tests/test-data/genomics/Illumina/150615_D00565_0087_AC6VG0ANXX/Unaligned/DemultiplexingStats.xml"

# %%
dms_dict = parsers.DemultiplexStatsParser(dmplexstats_file).parse_dict()

# %%
import pandas as pd

# %%
# !pip install xmltodict
import xmltodict

# %%
with open(dmplexstats_file) as fd:
    doc = xmltodict.parse(fd.read())

# %%
doc['Stats']['Flowcell']
# Out:
# OrderedDict([(u'@flowcell-id', u'C8B30ANXX'),
#              (u'Project',
#               [OrderedDict([(u'@name', u'default'),
#                             (u'Sample',
#                              [OrderedDict([(u'@name', u'Undetermined'),
#                                            (u'Barcode',
#                                             [OrderedDict([(u'@name',
#                                                            u'unknown'),
#                                                           (u'Lane',
#                                                            [OrderedDict([(u'@number',
#                                                                           u'1'),
#                                                                          (u'BarcodeCount',
#                                                                           u'3222151'),
#                                                                          (u'PerfectBarcodeCount',
# ...

# %%
d = {'id': 'thing1',
     'project': {'name': 'foo',
                 'sample': {'name': 'bar',
                            'barcode': 'baz'}}}
print(d)

def flatten_xml_dict(d, d2=None, key=None):
    print(d)
    if d2 is None:
        d2 = {}
    
    for k, v in d.items():
        if isinstance(v, dict):
            d2 = flatten_xml_dict(v, d2)
        else:
            if 'name' in k:
                k = 'project_{}'.format(k)
            d2.setdefault(k, []).append(v)
    return d2

flatten_xml_dict(d['project']['sample'])
# Out:
# {'project': {'sample': {'barcode': 'baz', 'name': 'bar'}, 'name': 'foo'}, 'id': 'thing1'}
# {'barcode': 'baz', 'name': 'bar'}
# {'barcode': ['baz'], 'project_name': ['bar']}

# %%
import collections
# dict2list = lambda dic: [(k, v) for (k, v) in dic.iteritems()]
name_not_all = lambda item: item['@name'] != 'all'

get_lane_details = lambda x: dict(x.items()) #{k: v for k, v in x.items()}
extract_fields = lambda x: {x['@name']: map(get_lane_details, x['Lane'])}

b = doc['Stats']['Flowcell']['Project'][0]['Sample'][0:1]
k = b[0].keys()
b[0][k[1]]
# f = filter(name_not_all, doc['Stats']['Flowcell']['Project'][0]['Sample'][0])


# map(lambda x: x, filter(name_not_all, b))

# pprint(doc['Stats']['Flowcell']['Project'][0]['Sample'][1]['Barcode'])

def unpack(item, key=None):
    unpack_dict = {}
    if isinstance(item, list):
        for i in item:
            unpack(item)
    if isinstance(item, dict):
        for k in item:
            unpack(item[k], k)
    else:
        print (key, item)
# print(b[0])
# print(isinstance(b[0], dict))
# print(b[0].keys())
# print(b[0][b[0].keys()[0]])
print(b[0][b[0].keys()[1]][0]['Lane'][0])

unpack(b[0][b[0].keys()[1]][0]['Lane'][0])
# Out:
# OrderedDict([(u'@number', u'1'), (u'BarcodeCount', u'3222151'), (u'PerfectBarcodeCount', u'3222151')])
# (u'@number', u'1')
# (u'BarcodeCount', u'3222151')
# (u'PerfectBarcodeCount', u'3222151')

# %%
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
b = dms_dict['Stats']['Flowcell']['Project'][0]['Sample'][0:1]

# %%
flatten(b[0])
# Out:
# {'Barcode': [{'Lane': [{'BarcodeCount': '3222151',
#      'PerfectBarcodeCount': '3222151',
#      'number': '1'},
#     {'BarcodeCount': '25352076',
#      'PerfectBarcodeCount': '25352076',
#      'number': '2'},
#     {'BarcodeCount': '25116427',
#      'PerfectBarcodeCount': '25116427',
#      'number': '3'},
#     {'BarcodeCount': '43836188',
#      'PerfectBarcodeCount': '43836188',
#      'number': '4'},
#     {'BarcodeCount': '44367529',
#      'PerfectBarcodeCount': '44367529',
#      'number': '5'},
#     {'BarcodeCount': '3398951',
#      'PerfectBarcodeCount': '3398951',
#      'number': '6'},
#     {'BarcodeCount': '3152223',
#      'PerfectBarcodeCount': '3152223',
#      'number': '7'},
#     {'BarcodeCount': '10183609',
#      'PerfectBarcodeCount': '10183609',
#      'number': '8'}],
#    'name': 'unknown'},
#   {'Lane': [{'BarcodeCount': '3222151',
#      'PerfectBarcodeCount': '3222151',
#      'number': '1'},
#     {'BarcodeCount': '25352076',
# ...

# %%
tree = ET.parse(dmplexstats_file)

# %%
tree

# %%
tree.getroot()
# Out:
# <Element 'Stats' at 0x10e407210>

# %%
root = tree.getroot()
print(root.text)
children = list(root)
for child in children[0:1]:
    print(child.tag)
    print(child.attrib)
    print(child.text)
# Out:
#
# Flowcell
# {'flowcell-id': 'C8B30ANXX'}

# %%
def xml_to_dict(root):
    current=None

    children=list(root)
    if children:
        current={}
        duplicates={}
        for child in children:
            if len(root.findall(child.tag))>1:
                if child.tag not in duplicates:
                    duplicates[child.tag]=[]
                lower=xml_to_dict(child)
                duplicates[child.tag].extend(lower.values())
                current.update(duplicates)
            else:
                lower=xml_to_dict(child)
                current.update(lower)
    if root.attrib:
        if current:
            if [x in current for x in root.attrib]:
                current.update(root.attrib)
            else:
                current.update({'attribs':root.attribs})
        else:
            current= root.attrib
    if root.text and root.text.strip() != "":
        if current:
            if 'text' not in current:
                current['text']=root.text
            else:
                #you're really pushing here, pal
                current['xml_text']=root.text
        else:
            current=root.text
    return {root.tag:current}

# %%
d = xml_to_dict(root)

# %%
def create_dataframe(data):
        df = pd.DataFrame(columns=('flowcell', 'project', 'sample', 'barcode', 'lane'))
        for i in range(len(data)):
                obj = data.getchildren()[i].getchildren()
                row = dict(zip(['name', 'lastname', 'email', 'domain', 'date'], [obj[0].text, obj[1].text, obj[2].text, obj[3].text, obj[4].text]))
                row_series = pd.Series(row)
                row_series.name = i
                df = df.append(row_series)
        return df
# Out:
# {'Project': [{'Sample': [{'Barcode': [{'Lane': [{'BarcodeCount': '3222151',
#          'PerfectBarcodeCount': '3222151',
#          'number': '1'},
#         {'BarcodeCount': '25352076',
#          'PerfectBarcodeCount': '25352076',
#          'number': '2'},
#         {'BarcodeCount': '25116427',
#          'PerfectBarcodeCount': '25116427',
#          'number': '3'},
#         {'BarcodeCount': '43836188',
#          'PerfectBarcodeCount': '43836188',
#          'number': '4'},
#         {'BarcodeCount': '44367529',
#          'PerfectBarcodeCount': '44367529',
#          'number': '5'},
#         {'BarcodeCount': '3398951',
#          'PerfectBarcodeCount': '3398951',
#          'number': '6'},
#         {'BarcodeCount': '3152223',
#          'PerfectBarcodeCount': '3152223',
#          'number': '7'},
#         {'BarcodeCount': '10183609',
#          'PerfectBarcodeCount': '10183609',
#          'number': '8'}],
#        'name': 'unknown'},
# ...
